# %% [markdown]
# Arun Ganesh \
# Final Report \
# CSC 369

# %% [markdown]
# # Introduction

# %% [markdown]
# I chose this dataset because as an avid consumer, I default to Amazon for easy and fast productional transactions. With this project, I am using a kaggle data set from here: https://www.kaggle.com/datasets/datafiniti/consumer-reviews-of-amazon-products.
#
#
# As a result the algorithm produces a top 5 of Amazon products that are suited to the user based on general review ratings:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Dataset

# %% [markdown]
# Within this Kaggle dataset is a list of over 34,000 consumer reviews for Amazon products like the Kindle, Fire TV Stick, and more provided by Datafiniti's Product Database. The data involved in this include ratings, reviews, basic product information.
#
# As an example, the structure of the header of each columns are:
#
# id \
# name \
# asins \
# brand \
# categories \
# keys \
# manufacturer \
# reviews.date \
# reviews.dateAdded \
# reviews.dateSeen \
# reviews.didPurchase \
# reviews.doRecommend \
# reviews.id \
# reviews.numHelpful \
# reviews.rating \
# reviews.sourceURLs \
# reviews.text \
# reviews.title \
# reviews.userCity \
# reviews.userProvince \
# reviews.username \

# %% [markdown]
# # Questions

# %% [markdown]
# Using a public dataset and PySpark how can we predict a top amount of Amazon products for a user?

# %% [markdown]
# We predict a certain amount of top user product based on the ALS model that complements PySpark SQL functions. Using this model, I associate an ID and distinct count with each review rating to see any high trends. I then calculate the Root Mean Square Error (RMSE) to enforce a regression model that can be easily applied to predict such outcomes.

# %% [markdown]
# What sort of machine learning model will be best with this approach?

# %% [markdown]
# I have used a K-Nearest Neigbhbors approach and Linear Regression but have found that the ALS model suits PySpark SQL the best and is much easier to use with SQL standard imports.

# %% [markdown]
# Is it better to use RDDs or Dataframes for this project?

# %% [markdown]
# As we are modifying columns and changing its format, a Dataframe will be better to use as it is easier to visualize for any future programmer/user. The use with dataframes is that SQL easily complements any altering behavior.

# %% [markdown]
# How do we filter through incorrectly inputted Amazon reviews?

# %% [markdown]
# I filter through Amazon reviews as every value/column contain a String besides the rating from 1-5 which is placed as an integer. Through these ratings, I associate a distinct ID and join them with productional values associated with the dataset. I then filter out any error or misinput that is placed within the Dataset through data cleaning and continue with the model from there.

# %% [markdown]
# # Problem Decomposition

# %% [markdown]
# How did you decompose your problems into appropriate distributed code?

# %% [markdown]
# I distribute the collections of data of review usernames and its associated ratings among a set of partitioned data within each Spark Dataframe. By grouping this data into named columns, it makes it easier to calculate which regression model which name of products should be associated for each user ID.

# %% [markdown]
# # Results

# %% [markdown]
# As a result for this analysis the algorithm calculates a top amount of products that would benefit the users depending on popular reviews and descriptions. The results may alter based on any incoming descriptions and any futher changes that affect the ALS model.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Conclusion

# %% [markdown]
# Overall, it was interesting to see how maching learning can be applied to PySpark. I also observed how useful SQL is within this context that RDDs and simple partitions cannot compete with. The use of joins are much more accessible within a dataframe. In the future, I would like to focus on other technologies that I could use to visualize and further automate these changes through dynamic system processing.
